# %%
#all imports
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('forPredictions/monthlyParkingRevenue.csv')
df.head()
# Out:
#    year      month    lot2    lot3    lot4    lot5  lot6  valet  prebook  \
# 0  2017       July  257917  154585  693701  470626     0  21675      0.0
# 1  2017     August  279513  166056  813997  462175     0  28450      0.0
# 2  2017  September  269087  161802  792354  433379     0  28200      0.0
# 3  2017    October  299692  182989  890444  455167     0  33100      0.0
# 4  2017   November  268278  185875  772522  404235     0  29850      0.0
#
#      revenue
# 0  1598504.0
# 1  1750191.0
# 2  1684822.0
# 3  1861392.0
# 4  1660760.0

# %%
df.columns
# Out:
# Index(['year', 'month', 'lot2', 'lot3', 'lot4', 'lot5', 'lot6', 'valet',
#        'prebook', 'revenue'],
#       dtype='object')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12,6))

# Line plot with markers
sns.lineplot(data=df, x='month', y='revenue', marker='o', color='green')

# Labels and title
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.title('Monthly Parking Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
